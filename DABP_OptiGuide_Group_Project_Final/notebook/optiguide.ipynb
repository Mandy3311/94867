# %%
import gurobipy as gp
from gurobipy import GRB
from eventlet.timeout import Timeout
import openai
from flaml import autogen
from flaml.autogen.agentchat import Agent, UserProxyAgent
from optiguide.optiguide import OptiGuideAgent
openai.api_key = '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'

# %%
autogen.oai.ChatCompletion.start_logging()

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": {
            # "gpt-4",
            # "gpt4",
            # "gpt-4-32k",
            # "gpt-4-32k-0314",
            "gpt-3.5-turbo",
            # "gpt-3.5-turbo-16k",
            # "gpt-3.5-turbo-0301",
            # "chatgpt-35-turbo-0301",
            # "gpt-35-turbo-v0301",
        }
    }
)

# %%
script_path1 = 'optim1.py'
with open(script_path1, 'r') as file:
    source_code1 = file.read()
script_path2 = 'optim1.py'
with open(script_path2, 'r') as file:
    source_code2 = file.read()
script_path3 = 'optim3.py'
with open(script_path3, 'r') as file:
    source_code3 = file.read()

# %%
# %%capture
agent1 = OptiGuideAgent(
    name="Marketing Agent",
    source_code=source_code1,
    debug_times=1,
    example_qa="",
    llm_config={
        "request_timeout": 600,
        "seed": 42,
        "config_list": config_list,
    }
)

agent2 = OptiGuideAgent(
    name="Marketing Agent",
    source_code=source_code2,
    debug_times=1,
    example_qa="",
    llm_config={
        "request_timeout": 600,
        "seed": 42,
        "config_list": config_list,
    }
)

agent3 = OptiGuideAgent(
    name="Marketing Agent",
    source_code=source_code3,
    debug_times=1,
    example_qa="",
    llm_config={
        "request_timeout": 600,
        "seed": 42,
        "config_list": config_list,
    }
)

user = UserProxyAgent(
    "user", max_consecutive_auto_reply=0,
    human_input_mode="NEVER", code_execution_config=False
)

# %%
user.initiate_chat(agent1, message="what if we decrease the max_calls by 10%")
# Out:
# user (to Marketing Agent):
#
# what if we decrease the max_calls by 10%
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # reduce the max_calls by 10%
# constraints['max_calls'] = constraints['max_calls'] * 0.9
#
# # Update the 'max_calls' constraint in the model
# for constr in m.getConstrs():
#     if constr.ConstrName == 'max_calls':
#         constr.setAttr('rhs', constraints['max_calls'])
#
# # Optimize model again
# m.optimize()
# if m.status == GRB.OPTIMAL:
#     print(f'Optimal value(maximized net profit): {m.objVal}')
# else:
#     print("Optimization was not successful.")
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # reduce the max_calls by 10%
# ...

# %%
user.initiate_chat(agent1, message="what if we increase max_duration by 10%")
# Out:
# user (to Marketing Agent):
#
# what if we increase max_duration by 10%
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Increase max duration constraints by 10%
# constraints['max_duration'] *= 1.10
# m.remove(m.getConstrByName('max_duration'))
# m.addConstr(quicksum(df.loc[i, 'duration'] * x[i] for i in df.index) <= constraints['max_duration'], name="max_duration")
#
# m.optimize()
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Increase max duration constraints by 10%
# constraints['max_duration'] *= 1.10
# m.remove(m.getConstrByName('max_duration'))
# ...

# %%
user.initiate_chat(agent1, message="what is the best combination of max_calls and max_duration, for max_calls in range of (500, 1500) with a step of 100, and max_duration in range of (5000, 15000) with a step of 1000?")
# Out:
# user (to Marketing Agent):
#
# what is the best combination of max_calls and max_duration, for max_calls in range of (500, 1500) with a step of 100, and max_duration in range of (5000, 15000) with a step of 1000?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# results = []
# for max_calls in range(500, 1500, 100):
#     for max_duration in range(5000, 15000, 1000):
#         constraints['max_calls'] = max_calls
#         constraints['max_duration'] = max_duration
#         # re-build the model
#         m = Model("marketing_campaign_optimization")
#         x = m.addVars(df.index, vtype=GRB.BINARY, name="x")
#         m.setObjective(
#             quicksum(profit_per_subscription['profit_per_subscription'] * df['P_i'][i] * x[i] for i in df.index) -
# ...

# %%
user.initiate_chat(agent3, message="How does the outcome change if we only target clients with a probability of subscription above 60%?")
# Out:
# user (to Marketing Agent):
#
# How does the outcome change if we only target clients with a probability of subscription above 60%?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Add probability constraint
# m.addConstr(quicksum(x[i] for i in df.index if df.loc[i, "P_i"] >= 0.6) >= constraints['min_primary'], "probability_constraint")
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Add probability constraint
# m.addConstr(quicksum(x[i] for i in df.index if df.loc[i, "P_i"] >= 0.6) >= constraints['min_primary'], "probability_constraint")
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# ...

# %%
user.initiate_chat(agent3, message="How does the outcome change if we only target clients with a probability of subscription above 40%?")
# Out:
# user (to Marketing Agent):
#
# How does the outcome change if we only target clients with a probability of subscription above 40%?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Add a high probability constraint
# m.addConstrs((x[i] == 0 for i in df.index if df['P_i'][i] <= 0.4), "high_prob")
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Add a high probability constraint
# m.addConstrs((x[i] == 0 for i in df.index if df['P_i'][i] <= 0.4), "high_prob")
#
# --- One-Word Answer: SAFE or DANGER ---
#
#
# --------------------------------------------------------------------------------
# safeguard (to Marketing Agent):
#
# SAFE
#
# ...

# %%
user.initiate_chat(agent3, message="what if there is an additional constraint that the overall subscription rate among the selected clients should be over 40%?")
# Out:
# user (to Marketing Agent):
#
# what if there is an additional constraint that the overall subscription rate among the selected clients should be over 40%?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Calculate the total number of customers
# total_customers = len(df.index)
#
# # Add subscriber constraint
# m.addConstr(quicksum(df.loc[i, 'P_i'] * x[i] for i in df.index)/total_customers >= 0.4, "min_subscription_rate")
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Calculate the total number of customers
# total_customers = len(df.index)
#
# # Add subscriber constraint
# ...

# %%
user.initiate_chat(agent3, message="What if profit_per_subscription increases by 10%?")
# Out:
# user (to Marketing Agent):
#
# What if profit_per_subscription increases by 10%?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Assign the increased profit_per_subscription
# profit_per_subscription = {'profit_per_subscription': 10 * 1.10}
#
# # Recalculate the Model's objective with the new profit_per_subscription
# m.setObjective(
#     quicksum(profit_per_subscription['profit_per_subscription'] * df['P_i'][i] * x[i] for i in df.index) -
#     quicksum(external_cost['cost_per_call'] * x[i] for i in df.index), GRB.MAXIMIZE)
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Assign the increased profit_per_subscription
# ...

# %%
user.initiate_chat(agent3, message="what if profit_per_subscription decreases by 10%?")
# Out:
# user (to Marketing Agent):
#
# what if profit_per_subscription decreases by 10%?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Decrease profit per subscription by 10%
# profit_per_subscription['profit_per_subscription'] *= 0.9
#
# # Recreate the model objective
# m.setObjective(
#     quicksum(profit_per_subscription['profit_per_subscription'] * df['P_i'][i] * x[i] for i in df.index) -
#     quicksum(external_cost['cost_per_call'] * x[i] for i in df.index), GRB.MAXIMIZE)
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Decrease profit per subscription by 10%
# profit_per_subscription['profit_per_subscription'] *= 0.9
#
# # Recreate the model objective
# ...

# %%
user.initiate_chat(agent3, message="what if cost per call increases by 20%, due to employees strike to demand wage increases?")
# Out:
# user (to Marketing Agent):
#
# what if cost per call increases by 20%, due to employees strike to demand wage increases?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # Adjust the cost per call due to employees strike
# external_cost["cost_per_call"] *= 1.20
#
# # Recreate the objective function
# m.setObjective(
#     quicksum(profit_per_subscription['profit_per_subscription'] * df['P_i'][i] * x[i] for i in df.index) -
#     quicksum(external_cost['cost_per_call'] * x[i] for i in df.index), GRB.MAXIMIZE)
#
# # Update and optimize the model
# m.update()
# m.optimize()
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # Adjust the cost per call due to employees strike
# ...

# %%
user.initiate_chat(agent3, message="what if cost per call decreases by 20%, for the bank outsource the phone call business and reduce labor costs?")
# Out:
# user (to Marketing Agent):
#
# what if cost per call decreases by 20%, for the bank outsource the phone call business and reduce labor costs?
#
# --------------------------------------------------------------------------------
# Marketing Agent (to writer):
#
#
# Answer Code:
#
#
# --------------------------------------------------------------------------------
# writer (to Marketing Agent):
#
# ```python
# # decrease external cost by 20%
# external_cost['cost_per_call'] *= 0.8
#
# # Update objective
# m.setObjective(
#     quicksum(profit_per_subscription['profit_per_subscription'] * df['P_i'][i] * x[i] for i in df.index) -
#     quicksum(external_cost['cost_per_call'] * x[i] for i in df.index), GRB.MAXIMIZE)
#
# # Solve
# m.update()
# m.optimize()
# ```
#
# --------------------------------------------------------------------------------
# Marketing Agent (to safeguard):
#
#
# --- Code ---
# # decrease external cost by 20%
# external_cost['cost_per_call'] *= 0.8
#
# ...
